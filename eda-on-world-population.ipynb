# %% [markdown]
# <div style="text-align: left; background-color:#E9F7EF; font-family: Trebuchet MS; color:#DFA06E; padding: 12px; line-height:1.25;border-radius:1px; margin-bottom: 0em; text-align: center; font-size: 58px;border-style: solid;border-color: dark green;">World Population Dataset</div>
# <div style="text-align: left; background-color:#DDD8F6; font-family: Monaco; color:#551184; padding: 12px; line-height:1.25;border-radius:1px; margin-bottom: 0em; text-align: center; font-size: 18px">🌎
# This Dataset contains Population data of every Country/Territory in the worldy 🌎</div>

# %% [markdown]
# ![population.jpg](attachment:population.jpg)

# %% [markdown]
# <a id='top'></a>
# <div class="list-group" id="list-tab" role="tablist">
#
# ## <div style="text-align: left; background-color:#DEF5B9; font-family: Trebuchet MS; color: #1D3E06; padding: 15px; line-height:1;border-radius:1px; margin-bottom: 0em; text-align: center; font-size: 25px;border-style: solid;border-color: dark green">TABLE OF CONTENTS📝</div>
#
# * [1. Objectives of Notebook](#1)
#
# * [2. Import Libraries](#2)
#
# * [3. Read and Explain Dataset](#3)
#     - [3.1. Reading dataset](#3.1)
#     - [3.2. Explain dataset](#3.2)
#
# * [4. Exploratory Data Analysis](#4)
#
# * [5. Data visualization](#5)
#     - [5.1. Population by Continent](#5.1)
#     - [5.2. Growth Rate](#5.2)
#     - [5.3. Area and population density](#5.3)
#     - [5.4. Number of Countries By Continent](#5.4)
#     - [5.5. Top 10 Countries with the most population](#5.5)
#     - [5.6. Top 10 Countries with the least population](#5.6)
#     - [5.7. Year-to-year population change of continents](#5.7)
#     - [5.8. Word Cloud of Country name](#5.8)
# * [6. Conclusion](#7)
# * [7. Authors Message](#8)

# %% [markdown]
# <a id="1"></a>
# ## <div style="text-align: left; background-color:#DEF5B9; font-family: Trebuchet MS; color:#1D3E06; padding: 15px; line-height:1;border-radius:1px; margin-bottom: 0em; text-align: center; font-size: 25px;border-style: solid;border-color: dark green">1. Objectives of Notebook 📌</div>

# %% [markdown]
# <div style="border-radius:10px;
#             border :#0A0104 solid;
#             padding: 15px;
#             background-color:#FFF0F5  ;
#            font-size:110%;
#             text-align: left">
#
# - 🔎Explore <mark>each attribute</mark> in the data;
#
# - 📈<mark>Population Analysis</mark> with <mark>(Continent, Year)</mark>;
#
# - 🗺️<mark>Growth rate Analysis</mark>;
#
# - 📉<mark>Analysis Area</mark> with <mark>Density</mark>;
#
# - 🌍Find <mark>top 10</mark> <mark>most populou</mark>s and <mark>least populous</mark> countries;

# %% [markdown]
# <a id="2"></a>
# ## <div style="text-align: left; background-color:#DEF5B9; font-family: Trebuchet MS; color:#1D3E06; padding: 15px; line-height:1;border-radius:1px; margin-bottom: 0em; text-align: center; font-size: 25px;border-style: solid;border-color: dark green">2. Import Libraries 📚</div>

# %%
#Importing all essential liabraries
import numpy as np
import pandas as pd

import seaborn as sns
from plotly.subplots import make_subplots
import matplotlib.pyplot as plt
import plotly.express as px
import missingno as msno
import plotly.offline as py
py.init_notebook_mode(connected=True)

import os
from wordcloud import WordCloud

import warnings
warnings.filterwarnings('ignore')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# <a id="3"></a>
# ## <div style="text-align: left; background-color:#DEF5B9; font-family: Trebuchet MS; color:#1D3E06; padding: 15px; line-height:1;border-radius:1px; margin-bottom: 0em; text-align: center; font-size: 25px;border-style: solid;border-color: dark green">3. Read and Explain Dataset 📝</div>

# %% [markdown]
# <a id="3.1"></a>
# ### <div style="text-align: left; background-color:#F0DCED; font-family:Trebuchet MS;color:#8F2A46; padding: 14px; line-height: 1;border-radius:10px;border-style: solid;border-color: dark pink">3.1 Reading dataset</div>

# %%
df = pd.read_csv('world_population.csv')

# %%
# Print sample
df.sample(8).reset_index(drop=True).style.set_properties(**{'background-color': '#E9F6E2','color': 'black','border-color': '#8b8c8c'})
# Out:
# <style type="text/css">
# ...

# %% [markdown]
# <a id="3.2"></a>
# ### <div style="text-align: left; background-color:#F2EDF3; font-family:Trebuchet MS;color: #8F2A46; padding: 14px; line-height: 1;border-radius:10px;border-style: solid;border-color: dark pink">3.2 Explain dataset</div>

# %% [markdown]
# <div style="border-radius:10px;
#             border :#0A0104 solid;
#             padding: 15px;
#             background-color:#E9F6E2;
#            font-size:110%;
#             text-align: left">
#     <span style="color:'black' ;"><center>📁 The dataset includes <mark>17 columns </mark></center></span>
#
#  * <mark>Rank</mark>: Rank by Population
#  * <mark>CCA3</mark>: 3 Digit Country/Territories Code
#  * <mark>Country</mark>: Name of the Country/Territories
#  * <mark>Capital</mark>: Name of the Capital
#  * <mark>Continent</mark>: Name of the Continent
#  * <mark>2022 Population</mark>: Population of the Country/Territories in the year 2022
#  * <mark>2020 Population</mark>: Population of the Country/Territories in the year 2020
#  * <mark>2015 Population</mark>: Population of the Country/Territories in the year 2015
#  * <mark>2010 Population</mark>: Population of the Country/Territories in the year 2010
#  * <mark>2000 Population</mark>: Population of the Country/Territories in the year 2000
#  * <mark>1990 Population</mark>: Population of the Country/Territories in the year 1990
#  * <mark>1980 Population</mark>: Population of the Country/Territories in the year 1980
#  * <mark>1970 Population</mark>: Population of the Country/Territories in the year 1970
#  * <mark>Area (km²)</mark>: Area size of the Country/Territories in square kilometer
#  * <mark>Density (per km²)</mark>: Population Density per square kilometer
#  * <mark>Growth Rate</mark>: Population Growth Rate by Country/Territories
#  * <mark>World Population Percentage</mark>: The population percentage by each Country/Territories

# %% [markdown]
# <a id="4"></a>
# ## <div style="text-align: left; background-color:#DEF5B9; font-family: Trebuchet MS; color:#1D3E06; padding: 15px; line-height:1;border-radius:1px; margin-bottom: 0em; text-align: center; font-size: 25px;border-style: solid;border-color: dark green">4. Exploratory Data Analysis 🔎</div>

# %%
df.head(10).style.set_properties(**{'background-color': '#E9F6E2','color': 'black','border-color': '#8b8c8c'})
# Out:
# <style type="text/css">
# ...

# %%
df.shape
# Out:
# (234, 17)

# %%
df.dtypes
# Out:
# Rank                             int64
# CCA3                            object
# Country                         object
# Capital                         object
# Continent                       object
# 2022 Population                  int64
# 2020 Population                  int64
# 2015 Population                  int64
# 2010 Population                  int64
# 2000 Population                  int64
# 1990 Population                  int64
# 1980 Population                  int64
# 1970 Population                  int64
# Area (km²)                       int64
# Density (per km²)              float64
# Growth Rate                    float64
# World Population Percentage    float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Rank                         234 non-null    int64
#  1   CCA3                         234 non-null    object
#  2   Country                      234 non-null    object
#  3   Capital                      234 non-null    object
#  4   Continent                    234 non-null    object
#  5   2022 Population              234 non-null    int64
#  6   2020 Population              234 non-null    int64
#  7   2015 Population              234 non-null    int64
#  8   2010 Population              234 non-null    int64
#  9   2000 Population              234 non-null    int64
#  10  1990 Population              234 non-null    int64
#  11  1980 Population              234 non-null    int64
#  12  1970 Population              234 non-null    int64
# ...

# %%
df.describe().T.sort_values(ascending=0, by="mean").style.background_gradient(cmap = "BuGn")
# Out:
# <style type="text/css">
# #T_bb9a2_row0_col0, #T_bb9a2_row1_col0, #T_bb9a2_row2_col0, #T_bb9a2_row3_col0, #T_bb9a2_row4_col0, #T_bb9a2_row5_col0, #T_bb9a2_row6_col0, #T_bb9a2_row7_col0, #T_bb9a2_row8_col0, #T_bb9a2_row8_col3, #T_bb9a2_row9_col0, #T_bb9a2_row9_col1, #T_bb9a2_row9_col2, #T_bb9a2_row9_col3, #T_bb9a2_row9_col4, #T_bb9a2_row9_col5, #T_bb9a2_row9_col6, #T_bb9a2_row9_col7, #T_bb9a2_row10_col0, #T_bb9a2_row10_col1, #T_bb9a2_row10_col2, #T_bb9a2_row10_col3, #T_bb9a2_row10_col4, #T_bb9a2_row10_col5, #T_bb9a2_row10_col6, #T_bb9a2_row10_col7, #T_bb9a2_row11_col0, #T_bb9a2_row11_col1, #T_bb9a2_row11_col2, #T_bb9a2_row11_col3, #T_bb9a2_row11_col4, #T_bb9a2_row11_col5, #T_bb9a2_row11_col6, #T_bb9a2_row11_col7, #T_bb9a2_row12_col0, #T_bb9a2_row12_col1, #T_bb9a2_row12_col2, #T_bb9a2_row12_col3, #T_bb9a2_row12_col4, #T_bb9a2_row12_col5, #T_bb9a2_row12_col6, #T_bb9a2_row12_col7 {
#   background-color: #f7fcfd;
#   color: #000000;
# }
# ...

# %%
df.nunique()
# Out:
# Rank                           234
# CCA3                           234
# Country                        234
# Capital                        234
# Continent                        6
# 2022 Population                234
# 2020 Population                234
# 2015 Population                234
# 2010 Population                234
# 2000 Population                234
# 1990 Population                234
# 1980 Population                234
# 1970 Population                234
# Area (km²)                     233
# Density (per km²)              234
# Growth Rate                    180
# World Population Percentage     70
# dtype: int64

# %%
df.corr()
# Out:
#                                  Rank  2022 Population  2020 Population  \
# Rank                         1.000000        -0.358361        -0.355854
# 2022 Population             -0.358361         1.000000         0.999946
# 2020 Population             -0.355854         0.999946         1.000000
# 2015 Population             -0.351222         0.999490         0.999763
# 2010 Population             -0.347461         0.998629         0.999105
# 2000 Population             -0.341057         0.994605         0.995583
# 1990 Population             -0.336152         0.987228         0.988724
# 1980 Population             -0.335246         0.980285         0.982121
# 1970 Population             -0.335379         0.973162         0.975254
# Area (km²)                  -0.383774         0.453411         0.454993
# Density (per km²)            0.129436        -0.027618        -0.027358
# Growth Rate                 -0.224561        -0.020863        -0.025116
# ...

# %%
msno.matrix(df)
plt.title('Distribution of Missing Values',fontsize=30, fontstyle= 'oblique');

# %% [markdown]
# **👉 There are total of <mark>234 countries</mark> and <mark>6 Continents</mark> in data.**
#
# **👉 There are a total of <mark>3978 observations</mark>.**
#
# **👉 Data contains <mark>no missing value</mark>.**

# %% [markdown]
# <a id="5"></a>
# ## <div style="text-align: left; background-color:#DEF5B9; font-family: Trebuchet MS; color:#1D3E06; padding: 15px; line-height:1;border-radius:1px; margin-bottom: 0em; text-align: center; font-size: 25px;border-style: solid;border-color: dark green">5. Data visualization 📉</div>

# %% [markdown]
# <a id="5.1"></a>
# ### <div style="text-align: left; background-color:#F0DCED; font-family:Trebuchet MS;color: #8F2A46; padding: 14px; line-height: 1;border-radius:10px;border-style: solid;border-color: dark pink">5.1. Population by Continent</div>

# %% [markdown]
# <div style="text-align: left; background-color:#DCEAF0; font-family:Trebuchet MS;color: #2A6C8F; padding:10px 10px;border-radius:12px 5px 12px 5px;width:60px;font-size: 18px;border-style: solid;border-color: dark green">2020</div>

# %%
fig1 = px.choropleth(df,
                     locations='Country',
                     locationmode='country names',
                     color='2022 Population',
                     color_continuous_scale=px.colors.sequential.Peach,
                     template='plotly_dark',
                     title = '2022 Population')

fig1.update_layout(font = dict(size = 17, family="Franklin Gothic"))

fig1.show()

# %%
population2022=df.groupby(by='Continent')['2022 Population'].sum()
fig=px.pie(values=population2022.values,
          names=population2022.index,
          color_discrete_sequence=px.colors.sequential.Mint,
          title= 'Population by Continent in 2022',template='plotly_dark'
          )
fig.update_traces(textinfo='label+percent+value', textfont_size=13,
                  marker=dict(line=dict(color='#100000', width=0.2)))

fig.data[0].marker.line.width = 2
fig.data[0].marker.line.color='gray'
fig.show()

# %% [markdown]
# <div style="text-align: left; background-color:#DCEAF0; font-family:Trebuchet MS;color: #2A6C8F; padding:10px 10px;border-radius:12px 5px 12px 5px;width:60px;font-size: 18px;border-style: solid;border-color: dark green">2020</div>

# %%
fig2 = px.choropleth(df,
                     locations='Country',
                     locationmode='country names',
                     color='2020 Population',
                     color_continuous_scale=px.colors.sequential.Peach,
                     template='plotly_dark',
                     title = '2020 Population')
fig2.update_layout(font = dict(size = 17, family="Franklin Gothic"))

fig2.show()

# %%
population2020=df.groupby(by='Continent')['2020 Population'].sum()
fig=px.pie(values=population2020.values,
          names=population2020.index,
          color_discrete_sequence=px.colors.sequential.Mint,
          title= 'Population by Continent in 2020',template='plotly_dark'
          )
fig.update_traces(textinfo='label+percent+value', textfont_size=13,
                  marker=dict(line=dict(color='#100000', width=0.2)))

fig.data[0].marker.line.width = 2
fig.data[0].marker.line.color='gray'
fig.show()

# %% [markdown]
# <div style="text-align: left; background-color:#DCEAF0; font-family:Trebuchet MS;color: #2A6C8F; padding:10px 10px;border-radius:12px 5px 12px 5px;width:60px;font-size: 18px;border-style: solid;border-color: dark green">2015</div>

# %%
fig3 = px.choropleth(df,
                     locations='Country',
                     locationmode='country names',
                     color='2015 Population',
                     color_continuous_scale=px.colors.sequential.Peach,
                     template='plotly_dark',
                     title = '2015 Population')
fig3.update_layout(font = dict(size = 17, family="Franklin Gothic"))

fig3.show()

# %%
population2015=df.groupby(by='Continent')['2015 Population'].sum()
fig=px.pie(values=population2015.values,
          names=population2015.index,
          color_discrete_sequence=px.colors.sequential.Mint,
          title= 'Population by Continent in 2015',template='plotly_dark'
          )
fig.update_traces(textinfo='label+percent+value', textfont_size=13,
                  marker=dict(line=dict(color='#100000', width=0.2)))

fig.data[0].marker.line.width = 2
fig.data[0].marker.line.color='gray'
fig.show()

# %% [markdown]
# <div style="text-align: left; background-color:#DCEAF0; font-family:Trebuchet MS;color: #2A6C8F; padding:10px 10px;border-radius:12px 5px 12px 5px;width:60px;font-size: 18px;border-style: solid;border-color: dark green">2010</div>

# %%
fig4 = px.choropleth(df,
                     locations='Country',
                     locationmode='country names',
                     color='2010 Population',
                     color_continuous_scale=px.colors.sequential.Peach,
                     template='plotly_dark',
                     title = '2010 Population')
fig4.update_layout(font = dict(size = 17, family="Franklin Gothic"))

fig4.show()

# %%
population2010=df.groupby(by='Continent')['2010 Population'].sum()
fig=px.pie(values=population2010.values,
          names=population2010.index,
          color_discrete_sequence=px.colors.sequential.Mint,
          title= 'Population by Continent in 2010',template='plotly_dark'
          )
fig.update_traces(textinfo='label+percent+value', textfont_size=13,
                  marker=dict(line=dict(color='#100000', width=0.2)))

fig.data[0].marker.line.width = 2
fig.data[0].marker.line.color='gray'
fig.show()

# %% [markdown]
# <div style="text-align: left; background-color:#DCEAF0; font-family:Trebuchet MS;color: #2A6C8F; padding:10px 10px;border-radius:12px 5px 12px 5px;width:60px;font-size: 18px;border-style: solid;border-color: dark green">2000</div>

# %%
fig5 = px.choropleth(df,
                     locations='Country',
                     locationmode='country names',
                     color='2000 Population',
                     color_continuous_scale=px.colors.sequential.Peach,
                     template='plotly_dark',
                     title = '2000 Population')
fig5.update_layout(font = dict(size = 17, family="Franklin Gothic"))

fig5.show()

# %%
population2000=df.groupby(by='Continent')['2000 Population'].sum()
fig=px.pie(values=population2000.values,
          names=population2000.index,
          color_discrete_sequence=px.colors.sequential.Mint,
          title= 'Population by Continent in 2000',template='plotly_dark'
          )
fig.update_traces(textinfo='label+percent+value', textfont_size=13,
                  marker=dict(line=dict(color='#100000', width=0.2)))

fig.data[0].marker.line.width = 2
fig.data[0].marker.line.color='gray'
fig.show()

# %% [markdown]
# <a id="5.2"></a>
# ### <div style="text-align: left; background-color:#F0DCED; font-family:Trebuchet MS;color: #8F2A46; padding: 14px; line-height: 1;border-radius:10px;border-style: solid;border-color: dark pink">5.2. Growth Rate</div>

# %%
#Growth Rate
fig = px.choropleth(df,
                     locations='Country',
                     locationmode='country names',
                     color='Growth Rate',
                     color_continuous_scale='Viridis',
                     template='plotly_dark',
                     title = 'Growth Rate')


fig.update_layout(font = dict(size = 17, family="Franklin Gothic"))

# %%
fig = px.scatter(df, x="2000 Population", y="Growth Rate",
                 size="2000 Population", color="Country",
                 log_x=True, size_max=50,
                 template='plotly_dark',
                 title="Area and population density",
                 marginal_y='rug')
fig.show()

# %% [markdown]
# <a id="5.3"></a>
# ### <div style="text-align: left; background-color:#F0DCED; font-family:Trebuchet MS;color: #8F2A46; padding: 14px; line-height: 1;border-radius:10px;border-style: solid;border-color: dark pink">5.3. Area and population density</div>

# %%
fig = px.scatter(df, x="Area (km²)", y="Density (per km²)",
                 size="Density (per km²)", color="Country",
                 log_x=True, size_max=50,
                 template='plotly_dark',
                 title="Area and population density",
                 marginal_y='rug')
fig.show()

# %% [markdown]
# <a id="5.4"></a>
# ### <div style="text-align: left; background-color:#F0DCED; font-family:Trebuchet MS;color: #8F2A46; padding: 14px; line-height: 1;border-radius:10px;border-style: solid;border-color: dark pink">5.4. Number of Countries By Continent</div>

# %%
country=df['Continent'].value_counts()
fig=px.bar(x=country.index,
          y=country.values,
          color=country.index,
          color_discrete_sequence=px.colors.sequential.BuGn,
          text=country.values,
          title= 'Number of Countries By Continent',
          template= 'plotly_dark')

fig.update_layout(xaxis_title="Countries",
                 yaxis_title="Count",
                 font=dict(size=15, family="Franklin Gothic"))

fig.show()

# %% [markdown]
# <a id="5.5"></a>
# ### <div style="text-align: left; background-color:#F0DCED; font-family:Trebuchet MS;color: #8F2A46; padding: 14px; line-height: 1;border-radius:10px;border-style: solid;border-color: dark pink">5.5. Top 10 Countries with the most population</div>

# %%
top_most_population = df.groupby(by = 'Country')['2022 Population'].sum().sort_values(ascending=False).head(10)

fig=px.bar(x=top_most_population.index,
          y=top_most_population.values,
          color=top_most_population.index,
          color_discrete_sequence=px.colors.sequential.PuBuGn,
          text=top_most_population.values,
          title="Top 10 Countries with the most population",
          template= 'plotly_dark')
fig.update_layout(
    xaxis_title="Countries",
    yaxis_title="Population",
    font = dict(size=15,family="Franklin Gothic"))
fig.show()

# %% [markdown]
# <a id="5.6"></a>
# ### <div style="text-align: left; background-color:#F0DCED; font-family:Trebuchet MS;color: #8F2A46; padding: 14px; line-height: 1;border-radius:10px;border-style: solid;border-color: dark pink">5.6. Top 10 Countries with the least population</div>

# %%
top_least_population = df.groupby(by = 'Country')['2022 Population'].sum().sort_values(ascending=True).head(10)

fig=px.bar(x=top_least_population.index,
          y=top_least_population.values,
          color=top_least_population.index,
          color_discrete_sequence=px.colors.sequential.PuBuGn,
          text=top_least_population.values,
          title="Top 10 Countries with the least population",
          template= 'plotly_dark')
fig.update_layout(
    xaxis_title="Countries",
    yaxis_title="Population",
    font = dict(size=15,family="Franklin Gothic"))
fig.show()

# %% [markdown]
# <a id="5.7"></a>
# ### <div style="text-align: left; background-color:#F0DCED; font-family:Trebuchet MS;color: #8F2A46; padding: 14px; line-height: 1;border-radius:10px;border-style: solid;border-color: dark pink">5.7. Year-to-year population change of continents</div>

# %%
features=df.columns
continent=df.groupby('Continent')[features].mean()
continent.sort_values(by='2022 Population', inplace=True)

# %%
population_features = ['2022 Population','2020 Population','2015 Population','2010 Population','2000 Population','1990 Population','1980 Population','1970 Population']

# %%
population_features.reverse()
plt.figure(figsize=(25,10))
for feature in population_features:
    plt.plot(continent[feature],label = feature)
plt.legend()
plt.title('Year-to-year population change of continents', size=25);
plt.show();

# %% [markdown]
# <a id="5.8"></a>
# ### <div style="text-align: left; background-color:#F0DCED; font-family:Trebuchet MS;color: #8F2A46; padding: 14px; line-height: 1;border-radius:10px;border-style: solid;border-color: dark pink">5.8. Word Cloud of Country name</div>

# %%
text = " ".join(subject_titles for subject_titles in df["Country"])
word_cloud = WordCloud(collocations = False, background_color = 'black', colormap = 'PuRd', min_font_size = 8).generate(text)
plt.figure(figsize = (20, 8))
plt.imshow(word_cloud, interpolation = 'bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# <a id="6"></a>
# ## <div style="text-align: left; background-color:#DEF5B9; font-family: Trebuchet MS; color:#1D3E06; padding: 15px; line-height:1;border-radius:1px; margin-bottom: 0em; text-align: center; font-size: 25px;border-style: solid;border-color: dark green">6. Conclusion 🐝</div>

# %% [markdown]
# <div style="border-radius:10px;
#             border :#0A0104 solid;
#             padding: 15px;
#             background-color:#FFF0F5;
#            font-size:110%;
#             text-align: left">
#    <span style="color:'black' ;"><center>🗺️ Some interesting things from the above analysis </mark>:</center></span>
#
# - The world's population is growing year by year (no sign of decreasing). According to current population growth estimates, the Earth will be overpopulated by 2050 or earlier.
#
# - China and India are the two countries with the largest population in the world (each country has more than 1.4 billion people).
#
# - Ukraine has the lowest population growth rate (0,912), while Moldova (the neighboring country of Ukraine) has the highest population growth rate (1,0691).
#
# - Macau is the most densely populated country in the world (23172,26667 per km^2) while the area is only 20 km^2.
#
# - The African continent has the highest growth rate compared to other continents.

# %% [markdown]
# <a id="7"></a>
# ## <div style="text-align: left; background-color:#DEF5B9; font-family: Trebuchet MS; color:#1D3E06; padding: 15px; line-height:1;border-radius:1px; margin-bottom: 0em; text-align: center; font-size: 25px;border-style: solid;border-color: dark green">8. Authors Message 🙇</div>

# %% [markdown]
# <p style="background-color:#FFF0F5 ;font-family:newtimeroman;color:#191618  ;font-size:130%;text-align:center;border-radius:20px 20px;"> If you liked this Notebook, please do upvote.<br> If you have any questions, feel free to comment!<br> ✨Best Wishes✨</p>

# %% [markdown]
# ## <div style="text-align: left; background-color:#DEF5B9; font-family: Trebuchet MS; color:#1D3E06; padding: 15px; line-height:1;border-radius:1px; margin-bottom: 0em; text-align: center; font-size: 25px;border-style: solid;border-color: dark green">Thank you for watching! 🙏</div>
